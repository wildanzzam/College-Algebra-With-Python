# %% [markdown]
# #### Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import io

# %% [markdown]
# #### Upload .csv File From Our Computer (One Option)

# %% [markdown]
# Vs Code

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file from the local directory
# df = pd.read_csv(r'path_to_your_file.csv')
df = pd.read_csv(r'path_to_your_file.csv')

# Display the first few rows of the DataFrame
print(df.head())

# Plotting example
df.plot(kind='bar')
plt.show()

# %% [markdown]
# Google Collab

# %%
uploaded = files.upload()
file_name = next(iter(uploaded))
table_1 = pd.read_csv(io.BytesIO(uploaded[file_name]))

# %% [markdown]
# #### Get .csv from a URL (another option)

# %%
# Data related to Old Faithful geyser eruptions
url = "https://people.sc.fsu.edu/~jburkardt/data/csv/faithful.csv"

table_1 = pd.read_csv(url)
table_1
# Out:
#      Index   "Eruption length (mins)"  Eruption wait (mins)
# 0        1                      3.600                    79
# 1        2                      1.800                    54
# 2        3                      3.333                    74
# 3        4                      2.283                    62
# 4        5                      4.533                    85
# ..     ...                        ...                   ...
# 267    268                      4.117                    81
# 268    269                      2.150                    46
# 269    270                      4.417                    90
# 270    271                      1.817                    46
# 271    272                      4.467                    74
#
# [272 rows x 3 columns]

# %% [markdown]
# Those imports and that url variable will be good for maybe 40 minutes, so we don't have to repeat steps each time. Now determne what columns we want and convert them to numpy arrays

# %%
# We could just display the whole table, but that might be too much
# table_1

# Get the headers so we can see the column names and 2 rows
print(table_1.head(2)) # by default if there is no number inside parenthesis it will be 5

# Column names as a variable
col_names = table_1.columns

# Another way to get column names
print("\n column names:")
for a in range(len(col_names)):
    print(a, " ", col_names[a])

# One more way
print("\n column names:")
for col in col_names:
    print(col)
# Out:
#    Index   "Eruption length (mins)"  Eruption wait (mins)
# 0      1                        3.6                    79
# 1      2                        1.8                    54
#
#  column names:
# 0   Index
# 1    "Eruption length (mins)"
# 2   Eruption wait (mins)
#
#  column names:
# Index
#  "Eruption length (mins)"
# Eruption wait (mins)

# %% [markdown]
# #### Graph Index and One Other Column as (x, y) points.

# %%
# Convert values to numpy arrays
x = table_1['Index'].to_numpy() # Put name the column
y = table_1[' "Eruption length (mins)"'].to_numpy()

# graph
xmin = x.min() - 5
xmax = x.max() + 5
ymin = y.min() - 5
ymax = y.max() + 5

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # Window size
plt.plot([xmin,xmax],[0,0],'b') # Blue x axis
plt.plot([0,0],[ymin,ymax],'b') # Blue y axis
plt.plot(x,y,'ro') # scatterplot
# plt.plot(x,y, 'b') # line graph
plt.show()

# %% [markdown]
# Change y value

# %%
# Convert values to numpy arrays
x = table_1['Index'].to_numpy() # Put name the column
y = table_1[' "Eruption length (mins)"'].to_numpy()

# graph
xmin = x.min() - 5
xmax = x.max() + 5
ymin = 0 # y.min() - 5
ymax = 6 # y.max() + 5

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # Window size
plt.plot([xmin,xmax],[0,0],'b') # Blue x axis
plt.plot([0,0],[ymin,ymax],'b') # Blue y axis
plt.plot(x,y,'ro') # scatterplot
# plt.plot(x,y, 'b') # line graph
plt.show()

# %% [markdown]
# #### Using Variables for Column Names

# %%
# Convert values to numpy arrays
x_name = col_names[0]
y_name = col_names[1]

x = table_1[x_name].to_numpy() # Put name the column
y = table_1[y_name].to_numpy()

# graph
xmin = x.min() - 5
xmax = x.max() + 5
ymin = 0 # y.min() - 5
ymax = 6 # y.max() + 5

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # Window size
plt.plot([xmin,xmax],[0,0],'b') # Blue x axis
plt.plot([0,0],[ymin,ymax],'b') # Blue y axis
plt.plot(x,y,'ro') # scatterplot
# plt.plot(x,y, 'b') # line graph
plt.show()

# %% [markdown]
# Change column name

# %%
# Convert values to numpy arrays
x_name = col_names[0]
y_name = col_names[2]

x = table_1[x_name].to_numpy() # Put name the column
y = table_1[y_name].to_numpy()

# graph
xmin = x.min() - 5 # make x min 1 if we want to remove 0
xmax = 50 # x.max() + 5
ymin =  y.min() - 5
ymax =  y.max() + 5

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # Window size
plt.plot([xmin,xmax],[0,0],'b') # Blue x axis
plt.plot([0,0],[ymin,ymax],'b') # Blue y axis
plt.plot(x,y,'ro') # scatterplot
plt.plot(x,y, 'b') # line graph
plt.show()

# %%
# Convert values to numpy arrays
x_name = col_names[0]
y_name = col_names[2]

x = table_1[x_name].to_numpy() # Put name the column
y = table_1[y_name].to_numpy()

# graph
xmin = 1 # make x min 1 if we want to remove 0
xmax = 50 # x.max() + 5
ymin =  y.min() - 5
ymax =  y.max() + 5

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # Window size
plt.plot([xmin,xmax],[0,0],'b') # Blue x axis
plt.plot([0,0],[ymin,ymax],'b') # Blue y axis
plt.plot(x,y,'ro') # scatterplot
plt.plot(x,y, 'b') # line graph
ax.set_xlabel(x_name)
ax.set_ylabel(y_name)
plt.show()

# %% [markdown]
# #### Meteostat Library for Graphing Weather Data
#
# May only need to install once

# %%
pip install meteostat
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: meteostat in c:\users\60115\appdata\roaming\python\python312\site-packages (1.6.7)
# Requirement already satisfied: pandas>=1.1 in c:\users\60115\appdata\roaming\python\python312\site-packages (from meteostat) (2.1.4)
# Requirement already satisfied: pytz in c:\users\60115\appdata\roaming\python\python312\site-packages (from meteostat) (2023.3.post1)
# Requirement already satisfied: numpy in c:\users\60115\appdata\roaming\python\python312\site-packages (from meteostat) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\60115\appdata\roaming\python\python312\site-packages (from pandas>=1.1->meteostat) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\60115\appdata\roaming\python\python312\site-packages (from pandas>=1.1->meteostat) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\60115\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas>=1.1->meteostat) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Columns:
#
# time, tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun
#
# - tavg = average temperature
# - tmin = minimum temperature
# - tmax = maximum temperature
# - prcp = Precipitation
# - snow = snow
# - wdir = wind direction
# - wspd = wind speed
# - wpgt = wind gust
# - pres = air pressure
# - tsun = the amount of sun
#
# Change start and end datetime
#
# Point is (latitude, longitude,meters above the ground)

# %%
from numpy.core.fromnumeric import mean
# Import Meteostat library and depedencies
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily
import numpy as np

# Documentation
# https://dev.meteostat.net/python/daily.html#data-structure

# Set time period
start = datetime(2022, 1, 1)
end = datetime(2022, 12, 31)

# Create Point for Vancouver, BC or Philadelphia, PA
# vancouver = Point(49.2497, -123.1193, 70)
philly = Point(39.99,-75.15,10)
burbs = Point(40.1,-75.2)

# Get daily data for 2022
daily_data = Daily(philly, start, end)
my_data = daily_data.fetch()
num_data = my_data['wspd'].to_numpy()
print("City mean = ", mean(num_data))

daily_data2 = Daily(burbs, start, end)
my_data2 = daily_data2.fetch()
num_data2 = my_data2['wspd'].to_numpy()
print("Suburbs mean = ", mean(num_data2))

# Plot line chart
x = np.linspace(1,357,365)
# my_data.plot(y=['wspd'])
# my_data2.plot(y=['wspd'])
plt.plot(x,my_data['wspd'])
plt.plot(x,my_data2['wspd'])
plt.show()
# Out:
# City mean =  14.404109589041095
# Suburbs mean =  8.763835616438357

# %% [markdown]
# #### Monthly Loop

# %%
from numpy.core.fromnumeric import mean
# Import Meteostat library and depedencies
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily
import numpy as np

# Documentation
# https://dev.meteostat.net/python/daily.html#data-structure

for m in range(1,11):
    # Set time period
    start = datetime(2022, m, 1)
    end = datetime(2022, m, 28)
    # # Create Point for Vancouver, BC or Philadelphia, PA
    # vancouver = Point(49.2497, -123.1193, 70)
    # philly = Point(39.99,-75.15,10)
    burbs = Point(40.1,-75.2)

    # Get the daily data for 2018
    daily_data = Daily(philly, start, end)
    my_data = daily_data.fetch()
    num_data = my_data['wspd'].to_numpy()
    print("Month",m, "mean = ", mean(num_data))
    # Plot line chart including average, minimum and maximum temperature
    my_data.plot(y=['wspd'])
    plt.show()
# Out:
# Month 1 mean =  16.192857142857143
# Month 2 mean =  15.132142857142856
# Month 3 mean =  16.607142857142858
# Month 4 mean =  17.117857142857144
# Month 5 mean =  14.332142857142859
# Month 6 mean =  13.375
# Month 7 mean =  13.175
# Month 8 mean =  12.335714285714285
# Month 9 mean =  12.967857142857142
# Month 10 mean =  13.710714285714285
