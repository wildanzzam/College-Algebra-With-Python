# %% [markdown]
# Add rulers by making grid True and legends

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 2*(xmax-xmin)
x = np.linspace(xmin, xmax, points)

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

ax.set_xlabel("x values")
ax.set_ylabel("y values")
ax.set_title("Some Graph")
ax.grid(True)

ax.set_xticks(np.arange(xmin, xmax, 1))
ax.set_yticks(np.arange(ymin, ymax, 1))

y = 2*x +1
plt.plot(x,y, label='y=2x+1')
plt.plot([4],[6], 'ro', label='point')
plt.plot(x,3*x, label='steeper line')
plt.legend()
plt.show()

# %% [markdown]
# ### Slope

# %%
x1 = 1
y1 = 7
x2 = 2
y2 = 10

slope = (y2 - y1) / (x2 - x1)

print("slope = ", slope)
# Out:
# slope =  3.0

# %% [markdown]
# Next, developing equations....

# %%
x1 = 1
y1 = 7
x2 = 2
y2 = 10

# The slope is "m"
m = (y2 - y1) / (x2 - x1)

# The y intercept is "b"
b = y1 - m*x1

# The full equation
print("y = ", m, "x + ", b)
# Out:
# y =  3.0 x +  4.0

# %% [markdown]
# Also display the graph

# %%
x1 = 1
y1 = 7
x2 = 2
y2 = 10

# Develop the equation y = mx + b
m = (y2 - y1) / (x2 - x1)
# The y intercept is "b"
b = y1 - m*x1
# The full equation
print("y = ", m, "x + ", b)

# For the graph
xmin = -10
xmax = 10
ymin = -10
ymax = 10

# For the line on the graph
y3 = m*xmin + b
y4 = m*xmax + b

# Basic setup for the graph
fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

# Plot the linear function as a red line
plt.plot([xmin, xmax], [y3, y4],'r')

plt.show()
# Out:
# y =  3.0 x +  4.0

# %% [markdown]
# Graph the solution

# %% [markdown]
# A town’s population increases at a constant rate. In 2010 the population was 55,000. By 2012 the population had increased to 76,000. If this continues, predict the population in 2016

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = 0
y1 = 55
x2 = 6
y2 = 76

# Develop the equation y = mx + b
m = (y2 - y1) / (x2 - x1)
b = y1 - m*x1
print("y = ", m, "x + ", b)

# For the graph
xmin = 0
xmax = 10
ymin = 0
ymax = 150 # We already started at 55, we are going to 76, and few years in the future 

# For the line on the graph
y3 = m*xmin + b 
y4 = m*xmax + b 

# Basic setup for the graph
fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

# Add details to the graph
ax.set_xlabel("time")
ax.set_ylabel("population")
ax.grid(True)
# ax.set_xtics(np.arrange(xmin, xmax, 2))
# ax.set_ytics(np.arrange(xmin, xmax, 2))


# Plot the linear function as a red line
plt.plot([xmin,xmax],[y3,y4],'r')

plt.show()
# Out:
# y =  3.5 x +  55.0

# %% [markdown]
# - The number of people afflicted with the common cold in the winter months dropped steadily by 50 each year since 2004 until 2010. In 2004, 875 people were inflicted.
#
#     Find the linear function that models the number of people afflicted with the common cold *C* as a function of the year, *t.* When will no one be afflicted?

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = 0
y1 = 875
x2 = 1
y2 = 825

# Develop the equation y = mx + b
m = (y2 - y1) / (x2 - x1)
b = y1 - m*x1
print("y = ", m, "x + ", b)


# For the graph
xmin = 0
xmax = 20
ymin = 0
ymax = 900 # We already started at 55, we are going to 76, and few years in the future 

# For the line on the graph
y3 = m*xmin + b 
y4 = m*xmax + b 

# Basic setup for the graph
fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

# Add details to the graph
ax.set_xlabel("time")
ax.set_ylabel("cases")
ax.grid(True)
# ax.set_xtics(np.arrange(xmin, xmax, 2))
# ax.set_ytics(np.arrange(xmin, xmax, 2))


# Plot the linear function as a red line
plt.plot([xmin,xmax],[y3,y4],'r')

plt.show()
# Out:
# y =  -50.0 x +  875.0

# %% [markdown]
# New Question: How to identify better the number of cases occurred each year?

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = 0
y1 = 875
x2 = 1
y2 = 825

# Develop the equation y = mx + b
m = (y2 - y1) / (x2 - x1)
b = y1 - m*x1
print("y = ", m, "x + ", b)
print("Number of people afflicted after 5 years : ", -50*5 + 875) # Number of People afflicted after 5 years

# For the graph
xmin = 0
xmax = 20
ymin = 0
ymax = 900 # We already started at 55, we are going to 76, and few years in the future 

# For the line on the graph
y3 = m*xmin + b 
y4 = m*xmax + b 

# Basic setup for the graph
fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

# Add details to the graph
ax.set_xlabel("time")
ax.set_ylabel("cases")
ax.grid(True)
# ax.set_xtics(np.arrange(xmin, xmax, 2))
# ax.set_ytics(np.arrange(xmin, xmax, 2))


# Plot the linear function as a red line
plt.plot([xmin,xmax],[y3,y4],'r')
plt.legend

plt.show()
# Out:
# y =  -50.0 x +  875.0
# Number of people afflicted after 5 years :  625

# %% [markdown]
# For the following exercise, use the graph in Figure 1 showing the profit y in thousands of dollars, of a company in a given year,x, where x represents years since 1980.
#
# Find the linear function x, where y depends on x, the number of years since 1980.

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = 5
y1 = 10
x2 = 25
y2 = 4

# Develop the equation y = mx + b
m = (y2 - y1) / (x2 - x1)
b = y1 - m*x1
print("y = ", m, "x + ", b)

# For the graph
xmin = 0
xmax = 50
ymin = 0
ymax = 15 # We already started at 55, we are going to 76, and few years in the future 

# For the line on the graph
y3 = m*xmin + b 
y4 = m*xmax + b 

# Basic setup for the graph
fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

# Add details to the graph
ax.set_xlabel("time")
ax.set_ylabel("profit")
ax.grid(True)
ax.set_xticks(np.arange(xmin, xmax, 2)) # Interval 2
ax.set_yticks(np.arange(xmin, xmax, 2)) # Interval 2


# Plot the linear function as a red line
plt.plot([xmin,xmax],[y3,y4],'r')
plt.legend

plt.show()
# Out:
# y =  -0.3 x +  11.5

# %% [markdown]
# **Find and interpret the `y-intercept`**
#
# For the following exercise, consider this scenario: In 2004, a school population was 1,700. By 2012 the population had grown to 2,500.
#
# Assume the population is changing linearly.
#
# 1. How much did the population grow between the year 2004 and 2012?
# 2. What is the average population growth per year?
# 3. Find an equation for the population `P` of the school `t` years after 2004

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = 0
y1 = 1700
x2 = 8 # 8 years from 2004 to 2012
y2 = 2500

# Develop the equation y = mx + b
m = (y2 - y1) / (x2 - x1)
b = y1 - m*x1
print("y = ", m, "x + ", b)

# For the graph
xmin = 0
xmax = 12
ymin = 0
ymax = 3000  

# For the line on the graph
y3 = m*xmin + b 
y4 = m*xmax + b 

# Basic setup for the graph
fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

# Add details to the graph
ax.set_xlabel("time")
ax.set_ylabel("population")
ax.grid(True)
# ax.set_xticks(np.arange(xmin, xmax, 2)) # Interval 2
# ax.set_yticks(np.arange(xmin, xmax, 2)) # Interval 2


# Plot the linear function as a red line
plt.plot([xmin,xmax],[y3,y4],'r')
plt.legend

plt.show()
print("a. The average growth per year is 100 from:", "y = ", m, "x + ", b)
# Out:
# y =  100.0 x +  1700.0
# a. The average growth per year is 100 from: y =  100.0 x +  1700.0

# %% [markdown]
# The amount of garbage, _`G`_ produced by a city with population _`*p*`_ is given by _`G = f(p)`_. _`G`_ is measured in tons per week and *`p`* is measured in thousands of people
#
# 1. The town of Tola has a population of `40,000` and produces `13 tons` of garbage each week. Express this information in terms of the function *`f`*
# 2. Explain the meaning of the statement *`f(5) = 2`*
#
# Note:
#
# - Population is an independent variable and garbage is dependent
# - population very often is an independent variable that causes a lot of other trends
# </aside>

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = 0
y1 = 0
x2 = 40 # 8 years from 2004 to 2012
y2 = 13

# Develop the equation y = mx + b
m = (y2 - y1) / (x2 - x1)
b = y1 - m*x1
print("y = ", m, "x + ", b)

# For the graph
xmin = 0
xmax = 100
ymin = 0
ymax = 50  

# For the line on the graph
y3 = m*xmin + b 
y4 = m*xmax + b 

# Basic setup for the graph
fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

# Add details to the graph
ax.set_xlabel("thousands")
ax.set_ylabel("tons")
ax.grid(True)
# ax.set_xticks(np.arange(xmin, xmax, 2)) # Interval 2
# ax.set_yticks(np.arange(xmin, xmax, 2)) # Interval 2


# Plot the linear function as a red line
plt.plot([xmin,xmax],[y3,y4],'r')
plt.legend

plt.show()
# Out:
# y =  0.325 x +  0.0

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = 0
y1 = 0
x2 = 2 # 8 years from 2004 to 2012
y2 = 5

# Develop the equation y = mx + b
m = (y2 - y1) / (x2 - x1)
b = y1 - m*x1
print("y = ", m, "x + ", b)

# For the graph
xmin = 0
xmax = 20
ymin = 0
ymax = 20  

# For the line on the graph
y3 = m*xmin + b 
y4 = m*xmax + b 

# Basic setup for the graph
fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

# Add details to the graph
ax.set_xlabel("thousands")
ax.set_ylabel("tons")
ax.grid(True)
# ax.set_xticks(np.arange(xmin, xmax, 2)) # Interval 2
# ax.set_yticks(np.arange(xmin, xmax, 2)) # Interval 2


# Plot the linear function as a red line
plt.plot([xmin,xmax],[y3,y4],'r')
plt.legend

plt.show()
# Out:
# y =  2.5 x +  0.0
