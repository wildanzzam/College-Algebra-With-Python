# %% [markdown]
# [![freeCodeCamp](https://cdn.freecodecamp.org/testable-projects-fcc/images/fcc_secondary.svg)](https://freecodecamp.org/)

# %% [markdown]
# **Learn Foundational Math 2 by Building Cartesian Graphs**<br>
# Each of these steps will lead you toward the Certification Project. Once you complete a step, click to expand the next step.

# %% [markdown]
# # &darr; **Do this first** &darr;
# Copy this notebook to your own account by clicking the `File` button at the top, and then click `Save a copy in Drive`. You will need to be logged in to Google. The file will be in a folder called "Colab Notebooks" in your Google Drive.

# %% [markdown]
# # Step 0 - Acquire the testing library

# %% [markdown]
# Please run this code to get the library file from FreeCodeCamp. Each step will use this library to test your code. You do not need to edit anything; just run this code cell and wait a few seconds until it tells you to go on to the next step.

# %%
# You may need to run this cell at the beginning of each new session

# !pip install requests

# This will just take a few seconds

import requests

# Get the library from GitHub
url = 'https://raw.githubusercontent.com/edatfreecodecamp/python-math/main/math-code-test-b.py'
r = requests.get(url)

# Save the library in a local working directory
with open('math_code_test_b.py', 'w') as f:
    f.write(r.text)

# Now you can import the library
import math_code_test_b as test

# This will tell you if the code works
test.step01()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\users\60115\appdata\roaming\python\python312\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\60115\appdata\roaming\python\python312\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\60115\appdata\roaming\python\python312\site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\60115\appdata\roaming\python\python312\site-packages (from requests) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\60115\appdata\roaming\python\python312\site-packages (from requests) (2024.2.2)
# Code test Passed
# Go on to the next step
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:21: SyntaxWarning: invalid escape sequence '\.'
#   if re.search("plt\.axis\(\[\-20\,\s*20\,\s*\-20\,\s*20\]\)", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:27: SyntaxWarning: invalid escape sequence '\.'
#   elif re.search("plt\.axis\(\[\-10\,\s*10\,\s*\-10\,\s*10\]\)", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:45: SyntaxWarning: invalid escape sequence '\s'
#   if re.search("xmax\s*=\s*20", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:51: SyntaxWarning: invalid escape sequence '\s'
#   elif re.search("xmax\s*=\s*10", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:73: SyntaxWarning: invalid escape sequence '\.'
#   if re.search("plt\.plot\(\[xmin\,xmax\]\,\[0\,0\]\,\s*\'g\'\)", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:77: SyntaxWarning: invalid escape sequence '\.'
#   elif re.search("plt\.plot\(\[xmin\,xmax\]\,\[0\,0\]\,\s*\'b\'\)", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:89: SyntaxWarning: invalid escape sequence '\.'
#   if re.search("plt\.plot\(\[0\,0\]\,\[ymin\,ymax\]\,\s*\'g\'\)", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:93: SyntaxWarning: invalid escape sequence '\.'
#   elif re.search("plt\.plot\(\[0\,0\]\,\[ymin\,ymax\]\,\s*\'b\'\)", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:119: SyntaxWarning: invalid escape sequence '\.'
#   if re.search("plt\.plot\(\[\-5\]\,\s*\[1\]\,\s*\'ro\'\)", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:141: SyntaxWarning: invalid escape sequence '\s'
#   if re.search("x\s*\=\s*\[4\,\s*1\,\s*2\]", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:151: SyntaxWarning: invalid escape sequence '\s'
#   if re.search("y\s*\=\s*\[2\,\s*1\,\s*5\]", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:179: SyntaxWarning: invalid escape sequence '\('
#   if re.search("plt.plot\(linex\,\s*liney\,\s*\'r\'\)", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:189: SyntaxWarning: invalid escape sequence '\('
#   if re.search("plt.plot\(pointx\,\s*pointy\,\s*\'gs\'\)", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:229: SyntaxWarning: invalid escape sequence '\.'
#   if re.search("plt\.plot\(x\,\s*\-x\s*\+\s*3\)", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:235: SyntaxWarning: invalid escape sequence '\.'
#   elif re.search("plt\.plot\(x\,\s*2\*x\s*\-\s*3\)", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:259: SyntaxWarning: invalid escape sequence '\s'
#   if re.search("y2\s*\=\s*\-x\s*\-\s*3", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:265: SyntaxWarning: invalid escape sequence '\s'
#   elif re.search("y2\s*\=\s*x\*\*2\s*\-\s*3", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:283: SyntaxWarning: invalid escape sequence '\('
#   if re.search("linsolve\(\[2\*x\s*\+\s*y\s*\-\s*15\,\s*3\*x\s*\-\s*y\],\s*\(x\,\s*y\)\)", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:289: SyntaxWarning: invalid escape sequence '\('
#   elif re.search("linsolve\(\[2\*x\s*\+\s*y\s*\-\s*1\,\s*x\s*\-\s*2\*y\s*\+\s*7\]\,\s*\(x\, y\)\)", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:331: SyntaxWarning: invalid escape sequence '\('
#   if re.search("f\(a\,b\)\:", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:339: SyntaxWarning: invalid escape sequence '\('
#   if re.search("f\(a\,\s*b\,\s*c\)\:", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:355: SyntaxWarning: invalid escape sequence '\('
#   if re.search("\(x\,\s*a\*x\*\*2\s*\+\s*b\*x\s*\+\s*c\)", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:371: SyntaxWarning: invalid escape sequence '\('
#   if re.search("\(f\,\s*a\=\(\-9\,\s*9\)\,\s*b\=\(\-9\,\s*9\)\,\s*c\=\(\-9\,\s*9\)\)", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:409: SyntaxWarning: invalid escape sequence '\s'
#   if re.search("vx\s*\=\s*\-b\/\(2\*a\)", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:419: SyntaxWarning: invalid escape sequence '\s'
#   if re.search("vy\s*\=\s*a\*vx\*\*2\s*\+\s*b\*vx\s*\+\s*c", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:451: SyntaxWarning: invalid escape sequence '\s'
#   if re.search("vx\s*\=\s*\-b\/\(2\*a\)", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:461: SyntaxWarning: invalid escape sequence '\s'
#   if re.search("vy\s*\=\s*a\*vx\*\*2\s*\+\s*b\*vx\s*\+\s*c", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:495: SyntaxWarning: invalid escape sequence '\s'
#   if re.search("x1\s*\=\s*\(\-b\s*\+\s*math\.sqrt\(b\*\*2\s*\-\s*4\*a\*c\)\)\/\(2\*a\)", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:505: SyntaxWarning: invalid escape sequence '\s'
#   if re.search("x2\s*\=\s*\(\-b\s*\-\s*math\.sqrt\(b\*\*2\s*\-\s*4\*a\*c\)\)\/\(2\*a\)", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:531: SyntaxWarning: invalid escape sequence '\.'
#   if re.search("rows\.append\(\[a\,\s*2\*a\]\)", code):
# c:\Users\60115\Documents\Study\Math\math_code_test_b.py:535: SyntaxWarning: invalid escape sequence '\.'
#   elif re.search("rows\.append\(\[a\,\s*3\*a\+2\]\)", code):

# %% [markdown]
# # Step 1 - Cartesian Coordinates

# %% [markdown]
# Learn Cartesian coordinates by building a scatterplot game. The Cartesian plane is the classic x-y coordinate grid (invented by Ren $\acute{e} $ DesCartes) where "<i>x</i>" is the horizontal axis and "<i>y</i>" is the vertical axis. Each (x,y) coordinate pair is a point on the graph. The point (0,0) is the "origin."
#
# The x value tells how much to move right (positive) or left (negative) from the origin. The y value tells you how much you move up (positive) or down (negative) from the origin. Notice that you are importing `matplotlib` to create the graph.
#
# The following code just displays one quadrant of the Cartesian graph. Just run this code to see how Python displays a graph.

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
plt.show()

# Just run this code to see a blank graph
import math_code_test_b as test
test.step01()
# Out:
# Code test Passed
# Go on to the next step

# %% [markdown]
# # Step 2 - Cartesian Coordinates (Part 2)

# %% [markdown]
# Here you will create a standard window but still not highlight each axis. Run this code once, then change the window size to 20 in each direction and run it again.

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

# Only change the numbers in the next line:
plt.axis([-20,20,-20,20])

plt.show()


# Only change code above this line
import math_code_test_b as test
test.step02(In[-1].split('# Only change code above this line')[0])
# Out:
#
# Code test passed
# Go on to the next step

# %% [markdown]
# # Step 3 - Graph Dimensions

# %% [markdown]
# When you look at this code, you can see how Python sets up window dimensions. You will also notice that it is easier and more organized to define the dimensions as variables. Run the code, then change just the `xmax` value to 20 and run it again to see the difference.

# %%
import matplotlib.pyplot as plt

# It is better to determine the window dimensions with variable
xmin = -20
xmax = 20
ymin = -20
ymax = 20

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.show()

# Only change code above this line
import math_code_test_b as test
test.step03(In[-1].split('# Only change code above this line')[0])
# Out:
#
# Code test passed
# Go on to the next step

# %% [markdown]
# # Step 4 - Displaying Axis Lines

# %% [markdown]
# Notice the code to `plot` a line for the x axis and a line for the y axis. The `'b'` makes the line blue. Run the code, then change each 'b' to 'g' to make the lines green.

# %%
import matplotlib.pyplot as plt

xmin = -10
xmax = 10
ymin = -10
ymax = 10

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'g') # blue x axis
plt.plot([0,0],[ymin,ymax], 'g') # blue y axis

plt.show()

# Only change code above this line
import math_code_test_b as test
test.step04(In[-1].split('# Only change code above this line')[0])
# Out:
#
# Code test passed
# Go on to the next step

# %% [markdown]
# # Step 5 - Plotting a Point

# %% [markdown]
# Now you will plot a point on the graph. Notice the `'ro'` makes the point a red dot. Run the code, then change the location of the point to (-5,1) and run it again. Keep the window size the same. Notice the difference between plotting a point and plotting a line.

# %%
import matplotlib.pyplot as plt

xmin = -10
xmax = 10
ymin = -10
ymax = 10

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

# Change only the numbers in the following line:
plt.plot([-5],[1], 'ro')

plt.show()


# Only change code above this line
import math_code_test_b as test
test.step05(In[-1].split('# Only change code above this line')[0])
# Out:
#
# Code test passed
# Go on to the next step

# %% [markdown]
# # Step 6 - Plotting Several Points

# %% [markdown]
# You have actually been using arrays to plot each singular point so far. In this step, you will see an array of x values and an array of y values defined before the plot statement. Notice that these two short arrays create one point: (4,2). Add two numbers to each array so that it also plots points (1,1) and (2,5).

# %%
import matplotlib.pyplot as plt

# only change the next two lines:
x = [4,1,1]
y = [2,5,1]

# Only change code above this line

xmin = -10
xmax = 10
ymin = -10
ymax = 10

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax],'b') # blue y axis

plt.plot(x, y, 'ro') # red points
plt.show()


# Only change code above this line
import math_code_test_b as test
test.step06(In[-1].split('# Only change code above this line')[0])
# Out:
#
# You should use x = [4,1,2] in your code
# You should use y = [2,1,5] in your code

# %% [markdown]
# # Step 7 - Plotting Points and Lines

# %% [markdown]
# Notice the subtle difference between plotting points and lines. Each `plot()` statement takes an array of x values, an array of y values, and a third argument to tell what you are plotting. The default plot is a line.
#
# The letters `'r'` and `'b'` (and `'g'` and a few others) indicate common colors. The "o" in `'ro'` indicates a dot, where `'rs'` would indicate a red square and `'r^'` would indicate a red triangle. Plot a red line and two green squares.

# %%
import matplotlib.pyplot as plt

# Use these numbers:
linex = [2,4]
liney = [1,5]
pointx = [1,6]
pointy = [6,3]

# Keep these lines:
xmin = -10
xmax = 10
ymin = -10
ymax = 10

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

# Change the next two lines:
plt.plot(linex,liney,'r')
plt.plot(pointx,pointy,'gs')

plt.show()


# Only change code above this line
import math_code_test_b as test
test.step07(In[-1].split('# Only change code above this line')[0])
# Out:
#
# Code test passed
# Go on to the next step

# %% [markdown]
# # Step 8 - Making a Scatterplot Game

# %% [markdown]
# To make the game, you can make a loop that plots a random point and asks the user to input the (x,y) coordinates. Notice the `for` loop that runs three rounds of the game. Run the code, play the game, then you can go on to the next step.

# %%
import matplotlib.pyplot as plt
import random

score = 0

xmin = -8
xmax = 8
ymin = -8
ymax = 8

fig, ax = plt.subplots()

for i in range(3): # by default start at 0
    xpoint = random.randint(xmin, xmax) #assign random int to coordinate x
    ypoint = random.randint(ymin, ymax) #assign random int to coordinate y
    x = [xpoint] # array
    y = [ypoint]
    plt.axis([xmin,xmax,ymin,ymax]) # window size
    plt.plot([xmin,xmax],[0,0],'b') # blue x axis
    plt.plot([0,0],[ymin,ymax], 'b') # blue y axis
    plt.plot(x, y, 'ro')
    print(" ")
    plt.grid() # displays grid lines on graph
    plt.show()
    # Guess the coordinate
    guess = input("Enter the coordinates of the red point point: \n")
    # Split the answer with comma
    guess_array = guess.split(",")
    xguess = int(guess_array[0])
    yguess = int(guess_array[1])
    if xguess == xpoint and yguess == ypoint:
        score = score + 1

print("Your score: ", score) # notice this is not in the loop


# Only change code above this line
import math_code_test_b as test
test.step08(score)
# Out:
# Your score:  3
# You scored 3 out of 3. Good job!
# You can go on to the next step

# %% [markdown]
# # Step 9 - Graphing Linear Equations

# %% [markdown]
# Besides graphing points, you can graph <i>linear equations</i> (or <i>functions</i>). The graph will be a straight line, and the equation will not have any exponents. For these graphs, you will import `numpy` and use the `linspace()` function to define the x values.
#
# That function takes three arguments: starting number, ending number, and number of steps. Notice the `plot()` function only has two arguments: the x values and a function (y = 2x - 3) for the y values. Run this code, then use the same x values to graph `y = -x + 3`.

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

x = np.linspace(-9,9,36)

# Only change the next line to graph y = -x + 3
plt.plot(x, 2*x - 3)



plt.show()


# Only change code above this line
import math_code_test_b as test
test.step09(In[-1].split('# Only change code above this line')[0])
# Out:
#
# Now change the equation and re-run the code.

# %% [markdown]
# # Step 10 - Creating Interactive Graphs

# %% [markdown]
# Like the previous graphs, you will graph a line. This time, you will create two sliders to change the <i>slope</i> and the <i>y intecept</i>. Notice the additional imports and other changes: You define a function with two arguments.
#
# All of the graphing happens within that `f(m,b)` function. The `interactive()` function calls your defined function and sets the boundaries for the sliders. Run this code then adjust the sliders and notice how they affect the graph.

# %%
# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

# Define the graphing function
def f(m, b):
    xmin = -10
    xmax = 10
    ymin = -10
    ymax = 10
    plt.axis([xmin,xmax,ymin,ymax]) # window size
    plt.plot([xmin,xmax],[0,0],'black') # black x axis
    plt.plot([0,0],[ymin,ymax], 'black') # black y axis
    plt.title('y = mx + b')
    x = np.linspace(-10, 10, 1000)
    plt.plot(x, m*x+b)
    plt.show()

# Set up the sliders
interactive_plot = interactive(f, m=(-9, 9), b=(-9, 9)) # giving range
interactive_plot


# Just run this code and use the sliders
import math_code_test_b as test
test.step01()
interactive_plot
# Out:
# Code test Passed
# Go on to the next step
# interactive(children=(IntSlider(value=0, description='m', max=9, min=-9), IntSlider(value=0, description='b', …

# %% [markdown]
# # Step 11 - Graphing Systems

# %% [markdown]
# When you graph two equations on the same coordinate plane, they are a <i>system of equations</i>. Notice how the `points` variable defines the number of points and the `linspace()` function uses that variable. Run this code to see the graph, then change `y2` so that it graphs y = -x - 3.

# %%
import matplotlib.pyplot as plt
import numpy as np


xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 2*(xmax-xmin)

# Define the x values once
x = np.linspace(xmin,xmax,points)

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

# line 1
y1 = 2*x
plt.plot(x, y1)

# line 2
y2 = -x - 3
plt.plot(x, y2)

plt.show()


# Only change code above this line
import math_code_test_b as test
test.step11(In[-1].split('# Only change code above this line')[0])
# Out:
#
# Code test passed
# Go on to the next step

# %% [markdown]
# # Step 12 - Systems of Equations - Algebra

# %% [markdown]
# In a system of equations, the solution is the point where the two equations intersect, the (x,y) values that work in each equation. To work with algabraic expressions, you will import `sympy` and define x and y as symbols. If you have two equations and two variables, set each equation equal to zero.
#
# The `linsolve()` function takes the non-zero side of each equation and the variables used. Notice the syntax. Run the code, then change the two equations to solve 2x + y - 15 = 0 and 3x - y = 0.

# %%
from sympy import *
x,y = symbols('x y')


# Change the equations in the following line:
print(linsolve([2*x + y - 15, 3*x - y], (x, y)))


# Only change code above this line
import math_code_test_b as test
test.step12(In[-1].split('# Only change code above this line')[0])
# Out:
# {(3, 9)}
#
# Code test passed
# Go on to the next step

# %% [markdown]
# # Step 13 - Solutions as Coordinates

# %% [markdown]
# The `linsolve()` function returns a <i>finite set</i>, and you can convert that "finite set" into (x,y) coordinates. Notice how the code parses the `solution` variable into two separate variables. Just run the code to see how this works.

# %%
from sympy import *
x,y = symbols('x y')

# Use variables for each equation
first = x + y
second = x - y

# parse finite set answer as coordinate pair
solution = linsolve([first, second], (x, y))
x_solution = solution.args[0][0]
y_solution = solution.args[0][1]

print("x = ", x_solution)
print("y = ", y_solution)
print(" ")
print("Solution: (",x_solution,",",y_solution,")")


# Just run this code
import math_code_test_b as test
test.step01()
# Out:
# x =  0
# y =  0
#
# Solution: ( 0 , 0 )
# Code test Passed
# Go on to the next step

# %% [markdown]
# # Step 14 - Systems from User Input

# %% [markdown]
# For more flexibility, you can get each equation as user input (instead of defining them in the code). Run this code and try it out - to solve any system of two equations.

# %%
from sympy import *

x,y = symbols('x y')
print("Remember to use Python syntax with x and y as variables")
print("Notice how each equation is already set equal to zero")
first = input("Enter the first equation: 0 = ")
second = input("Enter the second equation: 0 = ")
solution = linsolve([first, second], (x, y))
x_solution = solution.args[0][0]
y_solution = solution.args[0][1]

print("x = ", x_solution)
print("y = ", y_solution)


# Just run this code and test it with different equations
import math_code_test_b as test
test.step14()
# Out:
# Remember to use Python syntax with x and y as variables
# Notice how each equation is already set equal to zero
# x =  -1/2
# y =  5/2
#
# If you didn't get a syntax error, code test passed

# %% [markdown]
# # Step 15 - Solve and graph a system

# %% [markdown]
# Now you can put it all together: solve a system of equations, graph the system, and plot a point where the two lines intersect. Notice how this code is not like the previous solving equations code or the graphing code or the user input code.
#
# Python uses `sympy` to get the (x,y) solution and `numpy` to get the values to graph, so the user inputs nummerical values and the code uses them in two different ways. Think about how you would do this if the user input values for ax + by = c.

# %%
from sympy import *
import matplotlib.pyplot as plt
import numpy as np

print("First equation: y = mx + b")
mb_1 = input("Enter m and b, separated by a comma: ")
print("Enter m and b, separated by a comma: ", mb_1)
mb_in1 = mb_1.split(",")
m1 = float(mb_in1[0])
b1 = float(mb_in1[1])

print("Second equation: y = mx + b")
mb_2 = input("Enter m and b, separated by a comma: ")
print("Enter m and b, separated by a comma: ", mb_2)
mb_in2 = mb_2.split(",")
m2 = float(mb_in2[0])
b2 = float(mb_in2[1])

# Solve the system of equations
x,y = symbols('x y')
first = m1*x + b1 - y
second = m2*x + b2 - y
solution = linsolve([first, second], (x, y))
x_solution = round(float(solution.args[0][0]),3)
y_solution = round(float(solution.args[0][1]),3)

# Make sure the window includes the solution
xmin = int(x_solution) - 20
xmax = int(x_solution) + 20
ymin = int(y_solution) - 20
ymax = int(y_solution) + 20
points = 2*(xmax-xmin)

# Define the x values once for the graph
graph_x = np.linspace(xmin,xmax,points)

# Define the y values for the graph
y1 = m1*graph_x + b1
y2 = m2*graph_x + b2

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

# line 1
plt.plot(graph_x, y1)

# line 2
plt.plot(graph_x, y2)

# point
plt.plot([x_solution],[y_solution],'ro')

plt.show()
print(" ")
print("Solution: (", x_solution, ",", y_solution, ")")


# Run this code and test it with different equations
# Out:
# First equation: y = mx + b
# Enter m and b, separated by a comma:  3,5
# Second equation: y = mx + b
# Enter m and b, separated by a comma:  -1,6
#
# Solution: ( 0.25 , 5.75 )

# %% [markdown]
# # Step 16 - Quadratic Functions

# %% [markdown]
# Any function that involves x<sup>2</sup> is a "quadratic" function because "x squared" could be the area of a square. The graph is a parabola. The formula is y = ax<sup>2</sup> + bx + c, where `b` and `c` can be zero but `a` has to be a number. Here is a graph of the simplest parabola.

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 2*(xmax-xmin)
x = np.linspace(xmin,xmax,points)

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

y = x**2

plt.plot(x,y)
plt.show()

# Just run this code. The next step will transform the graph
import math_code_test_b as test
test.step01()
# Out:
# Code test Passed
# Go on to the next step

# %% [markdown]
# # Step 17 - Quadratic Function ABC's

# %% [markdown]
# Using the parabola formula y = ax<sup>2</sup> + bx + c, you will change the values of `a`, `b`, and `c` to see how they affect the graph. Run the code and use the sliders to change the values of `a` and `b`.
#
# Then change the code in the three places indicated to add a slider for `c`. You may remember this type of interactive graph from an earlier step. Move each slider to see how it affects the graph.

# %%
# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

# Change the next line to include c:
def f(a,b,c):
    plt.axis([-10,10,-10,10]) # window size
    plt.plot([-10,10],[0,0],'k') # blue x axis
    plt.plot([0,0],[-10,10], 'k') # blue y axis
    x = np.linspace(-10, 10, 1000)

    # Change the next line to add c to the end of the function:
    plt.plot(x, a*x**2 + b*x + c)
    plt.show()

# Change the next line to add a slider to change the c value
interactive_plot = interactive(f, a=(-9, 9), b=(-9,9), c=(-9,9))
interactive_plot


# Run the code once, then change the code and run it again

# Only change code above this line
import math_code_test_b as test
test.step17(In[-1].split('# Only change code above this line')[0])
interactive_plot
# Out:
# Code test passed
# Go on to the next step
# interactive(children=(IntSlider(value=0, description='a', max=9, min=-9), IntSlider(value=0, description='b', …

# %% [markdown]
# # Step 18 - Quadratic Functions - Vertex

# %% [markdown]
# The <i>vertex</i> is the point where the parabola turns around. The x value of the vertex is $\frac{-b}{2a}$ (and then you would calculate the y value to get the point). Write the code to find the vertex, given `a`, `b`, and `c` as inputs. Remember the parabola forumula is y = ax<sup>2</sup> + bx + c

# %%
import matplotlib.pyplot as plt
import numpy as np

# \u00b2 prints 2 as an exponent
print("y = ax\u00b2 + bx + c")

a = float(input("a = "))
b = float(input("b = "))
c = float(input("c = "))
print("a =", a)
print("b =", b)
print("c =", c)

# Write your code here, changing vx and vy
vx = -b/(2*a)
vy = a*vx**2 + b*vx + c


# Only change the code above this line

print(" (", vx, " , ", vy, ")")
print(" ")

xmin = int(vx)-10
xmax = int(vx)+10
ymin = int(vy)-10
ymax = int(vy)+10
points = 2*(xmax-xmin)
x = np.linspace(xmin,xmax,points)

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

plt.plot([vx],[vy],'ro') # vertex

x = np.linspace(vx-10,vx+10,100)
y = a*x**2 + b*x + c
plt.plot(x,y)

plt.show()


# Only change code above this line
import math_code_test_b as test
test.step18(In[-1].split('# Only change code above this line')[0])
# Out:
# y = ax² + bx + c
# a = 1.0
# b = -5.0
# c = 6.0
#  ( 2.5  ,  -0.25 )
#
# Code test passed
# Go on to the next step

# %% [markdown]
# # Step 19 - Projectile Motion

# %% [markdown]
# The path of every projectile is a parabola. For something thrown or launched upward,
# - the `a` value is -4.9 (meters per second squared);
# - the `b` value is the initial velocity (in meters per second);
# - the `c` value is the initial height (in meters);
#
# - the `x` value is time (in seconds); and
# - the `y` value is the height at that time.
#
# In this code, change `vx` and `vy` to represent the vertex. Plotting that (x,y) vertex point is already in the code.

# %%
import matplotlib.pyplot as plt
import numpy as np

a = -4.9
b = float(input("Initial velocity = "))
c = float(input("Initial height = "))
print("Initial Velocity = ", b)
print("Initial height = ", c)

# Change vx and vy to represent the vertex
vx = -b/(2*a) 
vy = a*vx**2 + b*vx + c


# Also change the following dimensions to display the vertex
xmin = -1
xmax = int(2*vx + 20)
ymin = -1
ymax = int(vy + 10)

# You do not need to change anything below this line
points = 4*(xmax-xmin)
x = np.linspace(xmin,xmax,points)
y = a*x**2 + b*x + c

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

plt.plot(x,y) # plot the line for the equation
plt.plot([vx],[vy],'ro') # plot the vertex point

print(" (", vx, ",", vy, ")")
print(" ")
plt.show()


# Only change code above this line
import math_code_test_b as test
test.step19(In[-1].split('# Only change code above this line')[0])
# Out:
# Initial Velocity =  40.0
# Initial height =  2.0
#  ( 4.081632653061225 , 83.63265306122447 )
#
# Code test passed
# Go on to the next step

# %% [markdown]
# # Step 20 - Quadratic Functions - C

# %% [markdown]
# Like many other functions, the `c` value (also called the "constant" because it is not a variable) affects the vertical shift of the graph. Run the following code to see how changing the `c` value changes the graph.

# %%
import matplotlib.pyplot as plt
import numpy as np
import time
from IPython import display

x = np.linspace(-4,4,16)
fig, ax = plt.subplots()
cvalue = "c = "

for c in range(10):
    y = -x**2+c
    plt.plot(x,y)
    cvalue = "c = ", c
    ax.set_title(cvalue)
    display.display(plt.gcf())
    time.sleep(0.5)
    display.clear_output(wait=True)

# Just run this code
import math_code_test_b as test
test.step01()
# Out:
# Code test Passed
# Go on to the next step

# %% [markdown]
# # Step 21 - The Quadratic Formula

# %% [markdown]
# For a projectile, you also need to find the point when it hits the ground. On a graph, you would call these points the "roots" or "x intercepts" or "zeros" (because y = 0 at these points).
#
# The <i>quadratic formula</i> gives you the x value when y = 0. Given `a`,`b` and `c`, here is the quadratic formula:<br>
#
# x = $\frac{-b \pm \sqrt{b^2 - 4ac}}{2a}$
#
# Notice it's the vertex plus or minus something: $\frac{-b}{2a} + \frac{\sqrt{b^2 - 4ac}}{2a}$ and $\frac{-b}{2a} - \frac{\sqrt{b^2 - 4ac}}{2a}$ <br>
#
# Write the code to output two x values, given a, b, and c as input. Use `math.sqrt()` for the square root.

# %%
import math

# \u00b2 prints 2 as an exponent
print("0 = ax\u00b2 + bx + c")
a = float(input("a = "))
b = float(input("b = "))
c = float(input("c = "))
print("a =", a)
print("b =", b)
print("c ", c)
x1 = 0
x2 = 0

# Check for non-real answers:
if b**2-4*a*c < 0: #
    print("No real roots")
else:
    # Write your code here, changing x1 and x2
    x1 = (-b + math.sqrt(b**2 - 4*a*c))/(2*a) #2a is our vertex
    x2 = (-b - math.sqrt(b**2 - 4*a*c))/(2*a) #2a is our vertex
    print("The roots are ", x1, " and ", x2)



# Only change code above this line
import math_code_test_b as test
test.step21(In[-1].split('# Only change code above this line')[0])
# Out:
# 0 = ax² + bx + c
# a = 1.0
# b = 5.0
# c  6.0
# The roots are  -2.0  and  -3.0
#
# Code test passed
# Go on to the next step

# %% [markdown]
# # Step 22 - Table of Values

# %% [markdown]
# In addition to graphing a function, you may need a table of values. This code shows how to make a simple table of (x,y) values. Run the code, then change the title to "y = 3x + 2" and change the function in the table.

# %%
import numpy as np
import matplotlib.pyplot as plt

ax = plt.subplot() # notice that we dont have fig 
ax.set_axis_off() #axes pff - we want table
title = "y = 3x + 2" # Change this title
cols = ('x', 'y')
rows = [[0,2]] #tupple of value x is 0 and y is 0
for a in range(1,10): 
    rows.append([a, 3*a+2]) # Change only the function in this line

ax.set_title(title)
plt.table(cellText=rows, colLabels=cols, cellLoc='center', loc='upper left')
plt.show()


# Only change code above this line
import math_code_test_b as test
test.step22(In[-1].split('# Only change code above this line')[0])
# Out:
#
# Code test passed
# Go on to the next step

# %% [markdown]
# # Step 23 - Projectile Game

# %% [markdown]
# Learn quadratic functions by building a projectile game. Starting at (0,0) you launch a toy rocket that must clear a wall. You can randomize the height and location of the wall. The goal is to determine what initial velocity would get the rocket over the wall. Bonus: make an animation of the path of the rocket.

# %%
# Write your code here
import matplotlib.pyplot as plt
import numpy as np
import random
import math

loc = random.randint(1,100)
h = random.randint(1,1000)
print("A toy rocket has to clear a wall ", loc, "meters away")
a = -4.9 
b = float(input("Initial velocity in m/s = "))
c = 0
print("Initial velocity in m/s = ", b)

# Change vx and vy to represent the vertex
vx = -b/(2*a)
vy = a*vx**2 + b*vx + c

# Also change x max
# Also change the following dimensions to display the vertex
xmin = -1
xmax = int(2*vx + 20)
ymin = -1
ymax = int(vy + 10)

# You do not need to change anything below this line
points = 2*(xmax-xmin)
x = np.linspace(xmin,xmax,points)
y = a*x**2 + b*x + c

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

# Line for target distance
plt.plot([loc,loc],[0,h], 'r')

plt.plot(x,y) # plot the parabola

root2 = round((-b - math.sqrt(b**2 - 4*a*c))/(2*a),2)
if root2>=loc:
    print("Distance: ", root2, "Success! ")
else:
    print("Missed it by that much ")

print(" ")

plt.show()


# Only change code above this line
import math_code_test_b as test
test.step19(In[-1].split('# Only change code above this line')[0])



# This step does not have a test
# Out:
# A toy rocket has to clear a wall  77 meters away
# Initial velocity in m/s =  400.0
# Distance:  81.63 Success!
#
# Code test passed
# Go on to the next step

# %% [markdown]
# # Step 24 - Define Graphing Functions

# %% [markdown]
# Building on what you have already done, create a menu with the following options:<br>
# <ul>
# <li>Display the graph and a table of values for any "y=" equation input</li>
# <li>Solve a system of two equations without graphing</li>
# <li>Graph two equations and plot the point of intersection</li>
# <li>Given a, b and c in a quadratic equation, plot the roots and vertex</li>
# </ul>
# Then think about how you will define a function for each item.

# %%
# Write your code here
import matplotlib.pyplot as plt
import numpy as np
import random
import math

print("Graph calculator menu: ")
print("1. Display the graph and table")
print("2. Graph 2 equations without graphing") 
print("3. Grap 2 equations and plot the point of intersection")
print("4. Plot the roots and vertex")
print("5. Quit")

# Prompt the option for the user to choose
option = input("Choose Option 1 - 5 ") 

# define function for displaying the graph and table
def display_graph_and_table(equation):
    # make window size
    xmin, xmax = -10, 10
    ymin, ymax = -10, 10
    # make points that will range the x and y value
    points = 2 * (xmax - xmin)

    # Make your graph smooth
    x = np.linspace(xmin, xmax, points)
    # Evaluation the Equation for Plotting
    # Input:The equation parameter is a string representing a mathematical expression involving x (e.g., "2*x + 3")
    # Process: The eval function evaluates this string as a Python expression.
    # Context: Before calling eval, x is an array of values generated by np.linspace(xmin, xmax, points).
    # Evaluation: eval then evaluates this modified string to compute the corresponding y value
    # Result: rows is a list of [xi, yi] pairs, where yi is the value of the equation evaluated at xi. 
    y = eval(equation)

    # Making figure
    fig, ax = plt.subplot()
    plt.axis([xmin, xmax, ymin, ymax])
    # Make the line axis for x
    plt.plot([xmin, xmax], [0,0], 'b')
    # Make the line axis for y
    plt.plot([0,0],[ymin, ymax], 'b')
    plt.plot(x, y)

    # Making List Comprehension that iterates over a range of integer values from xmin to xmax
    # this syntax Creating rows for the table [[xi, eval(equation.replace("x", str(xi)))]
    rows = [[xi, eval(equation.replace("x", str(xi)))] for xi in range(xmin, xmax + 1)]  
    ax.set_title(equation)
    plt.table(cellText=rows, colLabels=('x', 'y'), cellLoc='center', loc='upper left')
    plt.show()

# eq1 and eq2 are strings representing equations in the form "a b c", where a*x + b*y = c.
def solve_system_of_equations(eq1, eq2):
    # Map make iterable function that will turn each of a, b and c into float and split it wiht comma

    a1, b1, c1 = map(float, eq1. split())
    a2, b2, c2 = map(float, eq2. split())

    determinant = a1 * b2 - a2 * b1
    if determinant == 0:
        print("The system has no unique solution.")
    else:
        x = (c1 * b2 - c2 * b1) / determinant
        y = (a1 * c2 - a2 * c1) / determinant
        print(f"The solution is x = {x}, y = {y}")

def graph_two_equations_and_plot_intersection(eq1,eq2):
    # make window size
    xmin, xmax = -10, 10
    ymin, ymax = -10, 10
    # make points that will range the x and y value
    points = 2 * (xmax - xmin)

    x = np.linspace(xmin, xmax, points)
    y1 = eval(eq1)
    y2 = eval(eq2)

    # Making figure
    fig, ax = plt.subplots()
    plt.axis([xmin, xmax, ymin, ymax])
    # Make the line axis for x
    plt.plot([xmin, xmax], [0,0], 'b')
    # Make the line axis for y
    plt.plot([0,0],[ymin, ymax], 'b')
    # These lines plot the evaluated equations y1 and y2 against x
    # and add a label to each plot using the provided equations eq1 and eq2
    plt.plot(x, y1, label=f"{eq1}") 
    plt.plot(x, y2, label=f"{eq2}") 

    # Add legends
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.legend()

    # This is a coefficient matrix for the system of linear equations derived from the two equations eq1 and eq2
    A = np.array([[eval(eq1.replace('x', '1').replace('y', '0')), eval(eq1.replace('x', '0').replace('y', '1'))], 
                  [eval(eq2.replace('x', '1').replace('y', '0')), eval(eq2.replace('x', '0').replace('y', '1'))]])
    # This is a constant vector for the same system.
    b = np.array([eval(eq1.replace('x', '0').replace('y', '0')), 
                  eval(eq2.replace('x', '0').replace('y', '0'))])
    try:
        intersection = np.linalg.solve(A, b)
        plt.plot(intersection[0], intersection[1], 'ro')
        print(f"Intersection point: {intersection}")
    except np.linalg.LinAlgError:
        print("The lines do not intersect or are parallel.")

    plt.legend()
    plt.show()

def plot_quadratic_roots_and_vertex(a, b, c):
    xmin, xmax = -10, 10
    ymin, ymax = -10, 10
    points = 2 * (xmax - xmin)

    x = np.linspace(xmin, xmax, points)
    y = a * x**2 + b * x + c

    fig, ax = plt.subplots()
    plt.axis([xmin, xmax, ymin, ymax])
    plt.plot([xmin, xmax], [0, 0], 'b')
    plt.plot([0, 0], [ymin, ymax], 'b')
    plt.plot(x, y)

    vertex_x = -b / (2 * a)
    vertex_y = a * vertex_x**2 + b * vertex_x + c
    plt.plot(vertex_x, vertex_y, 'ro')

    discriminant = b**2 - 4 * a * c
    if discriminant >= 0:
        root1 = (-b + math.sqrt(discriminant)) / (2 * a)
        root2 = (-b - math.sqrt(discriminant)) / (2 * a)
        plt.plot(root1, 0, 'go')
        plt.plot(root2, 0, 'go')
        print(f"Roots: {root1}, {root2}")
    else:
        print("No real roots")

    print(f"Vertex: ({vertex_x}, {vertex_y})")
    plt.show()

def main():
    while True:
        print("\nGraph calculator menu: ")
        print("1. Display the graph and table for any 'y=' equation")
        print("2. Solve a system of two equations without graphing")
        print("3. Graph two equations and plot the point of intersection")
        print("4. Given a, b and c in a quadratic equation, plot the roots and vertex")
        print("5. Quit")

        option = input("Choose Option 1 - 5: ") 

        if option == '1':
            equation = input("Enter a 'y=' equation (e.g., 2*x+3): ")
            display_graph_and_table(equation)
        elif option == '2':
            eq1 = input("Enter the first equation in the form 'a b c' where 'a*x + b*y = c': ")
            eq2 = input("Enter the second equation in the form 'a b c' where 'a*x + b*y = c': ")
            solve_system_of_equations(eq1, eq2)
        elif option == '3':
            eq1 = input("Enter the first 'y=' equation (e.g., 2*x+3): ")
            eq2 = input("Enter the second 'y=' equation (e.g., -x-3): ")
            graph_two_equations_and_plot_intersection(eq1, eq2)
        elif option == '4':
            a = float(input("Enter coefficient a: "))
            b = float(input("Enter coefficient b: "))
            c = float(input("Enter coefficient c: "))
            plot_quadratic_roots_and_vertex(a, b, c)
        elif option == '5':
            print("Exiting the calculator. Goodbye!")
            break
        else:
            print("Invalid option. Please choose a number from 1 to 5.")

if __name__ == "__main__":
    main()
# This step does not have a test
# Out:
# Graph calculator menu:
# 1. Display the graph and table
# 2. Graph 2 equations without graphing
# 3. Grap 2 equations and plot the point of intersection
# 4. Plot the roots and vertex
# 5. Quit
#
# Graph calculator menu:
# 1. Display the graph and table for any 'y=' equation
# 2. Solve a system of two equations without graphing
# 3. Graph two equations and plot the point of intersection
# 4. Given a, b and c in a quadratic equation, plot the roots and vertex
# 5. Quit
# Invalid option. Please choose a number from 1 to 5.
#
# Graph calculator menu:
# 1. Display the graph and table for any 'y=' equation
# 2. Solve a system of two equations without graphing
# 3. Graph two equations and plot the point of intersection
# 4. Given a, b and c in a quadratic equation, plot the roots and vertex
# 5. Quit
# Exiting the calculator. Goodbye!

# %% [markdown]
# # Step 25 - Certification Project 2

# %% [markdown]
# Build a graphing calculator that performs the functions mentioned in the previous step:
# <ul>
# <li>Display the graph and a table of values for any "y=" equation input</li>
# <li>Solve a system of two equations without graphing</li>
# <li>Graph two equations and plot the point of intersection</li>
# <li>Given a, b and c in a quadratic equation, plot the roots and vertex</li>
# </ul>
# Define each of the functions, and make each option call a function.

# %%
# Write your code here


# This step does not have a test
