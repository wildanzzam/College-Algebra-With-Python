# %% [markdown]
# Use numpy library instead of a loop

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10

# Define how many points to plot 
points = 10*(xmax-xmin)

# Define the array of x values once
x = np.linspace(xmin,xmax,points)

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

# line 1
y1 = 3*x
plt.plot(x, y1) 

# line 2
y2 = x**3
plt.plot(x, y2) 

ax.grid(True)
plt.show()

# %% [markdown]
# #### Extra Problem

# %% [markdown]
# Shading and graphing inequalities

# %%
import matplotlib.pyplot as plt
import numpy as np

xmin = -10
xmax = 10
ymin = -10
ymax = 10
points = 2*(xmax-xmin)
x = np.linspace(xmin,xmax,points)

fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

# line 1
y1 = x+6
plt.plot(x, y1,'-')
plt.fill_between(x, y1, ymax, facecolor='red')

# line 2
y2 = x+3
plt.plot(x, y2,'-')
plt.fill_between(x, y2, y1, facecolor='yellow')

# line 3
y3 = x-1
plt.plot(x, y3)
plt.fill_between(x, y3, y2, facecolor='green')

# line 4
y4 = x-4
plt.plot(x, y4)
plt.fill_between(x, y4, y3, facecolor='blue')

plt.show()

# %%
# !pip install ipywidgets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipywidgets in c:\users\60115\appdata\roaming\python\python312\site-packages (8.1.3)
# Requirement already satisfied: comm>=0.1.3 in c:\users\60115\appdata\roaming\python\python312\site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\60115\appdata\roaming\python\python312\site-packages (from ipywidgets) (8.19.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\60115\appdata\roaming\python\python312\site-packages (from ipywidgets) (5.14.1)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in c:\users\60115\appdata\roaming\python\python312\site-packages (from ipywidgets) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in c:\users\60115\appdata\roaming\python\python312\site-packages (from ipywidgets) (3.0.11)
# Requirement already satisfied: decorator in c:\users\60115\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\60115\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\60115\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\60115\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\60115\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\60115\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: colorama in c:\users\60115\appdata\roaming\python\python312\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\60115\appdata\roaming\python\python312\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\60115\appdata\roaming\python\python312\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\60115\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\60115\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\60115\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\60115\appdata\roaming\python\python312\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)

# %% [markdown]
# Interactive Graphs

# %%
# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

# Define the graphing function
def f(m, b, zoom):
    xmin = -zoom
    xmax = zoom
    ymin = -zoom
    ymax = zoom
    points = 10*xmax-xmin
    x = np.linspace(xmin, xmax, points)

    plt.axis([xmin,xmax,ymin,ymax]) # window size
    plt.plot([xmin,xmax],[0,0],'black') # black x axis
    plt.plot([0,0],[ymin,ymax], 'black') # black y axis
    plt.title('y = mx + b')
    
    # Line 1
    y1 = 3*x**2 - 4
    
    # Line 2
    plt.plot(x, m*x+b)
    plt.show()
    # plt.fill_between(x, y3, y2, facecolor='blue')

# Set up the sliders
interactive_plot = interactive(f, m=(-9, 9), b=(-9, 9), zoom=(1,100))
interactive_plot
# Out:
# interactive(children=(IntSlider(value=0, description='m', max=9, min=-9), IntSlider(value=0, description='b', …

# %% [markdown]
# Graphing weather data

# %%
pip install meteostat
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting meteostat
#   Downloading meteostat-1.6.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pandas>=1.1 in c:\users\60115\appdata\roaming\python\python312\site-packages (from meteostat) (2.1.4)
# Requirement already satisfied: pytz in c:\users\60115\appdata\roaming\python\python312\site-packages (from meteostat) (2023.3.post1)
# Requirement already satisfied: numpy in c:\users\60115\appdata\roaming\python\python312\site-packages (from meteostat) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\60115\appdata\roaming\python\python312\site-packages (from pandas>=1.1->meteostat) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\60115\appdata\roaming\python\python312\site-packages (from pandas>=1.1->meteostat) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\60115\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas>=1.1->meteostat) (1.16.0)
# Downloading meteostat-1.6.7-py3-none-any.whl (31 kB)
# Installing collected packages: meteostat
# Successfully installed meteostat-1.6.7
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Columns:
#
# time, tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun
#
# - tavg = average temperature
# - tmin = minimum temperature
# - tmax = maximum temperature
# - prcp = Precipitation
# - snow = snow
# - wdir = wind direction
# - wspd = wind speed
# - wpgt = wind gust
# - pres = air pressure
# - tsun = the amount of sun

# %%
# Import Meteostat library and dependencies
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

# Documentation
# https://dev.meteostat.net/python/daily.html#data-structure

# Set time period
start = datetime(2022, 1, 1)
end = datetime(2022, 7, 31)

# Create Point for Vancouver,BC or Philadelphia, PA
#vancouver = Point(49.2497, -123.1193, 70)
philly = Point(39.97,-75.13,25)

# Get daily data for 2018
data = Daily(philly, start, end)
data = data.fetch()

# Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg', 'prcp','snow'])
plt.show()

# %% [markdown]
# Trial

# %%
# Import Meteostat library and dependencies
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

# Documentation
# https://dev.meteostat.net/python/daily.html#data-structure

# Set time period
start = datetime(2024, 1, 1) # YYYYMD
end = datetime(2024, 6, 8)

# Create Point for  Albukhary International University
#AIU = Point(6.133948481462801, 100.38646146687059)
AIU = Point(6.133948481462801, 100.38646146687059) # Latitude and Magnitude

# Get daily data for 2018
data = Daily(AIU, start, end)
data = data.fetch()

# Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg', 'prcp','tmax','tsun'])
plt.show()
