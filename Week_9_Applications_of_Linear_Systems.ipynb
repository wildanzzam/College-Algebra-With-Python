# %% [markdown]
# ### Applications of Linear Systems

# %% [markdown]
# #### Slope-intercept equation from two points

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = 0
y1 = 32
x2 = 100
y2 = 212

# Develop the equation y = mx + b
m = (y2 - y1) / (x2 - x1)
b = y1 - m*x1
print("y = ", m, "x + ", b)

# For the graph
xmin = 0
xmax = 10
ymin = 0
ymax = 500

# For the line on the graph
y3 = m*xmin + b
y4 = m*xmax + b

# Basic setup for the graph
fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

# Add details to the graph
ax.set_xlabel("x values")
ax.set_ylabel("y values")
ax.grid(True)
#ax.set_xticks(np.arange(xmin, xmax, 2))
#ax.set_yticks(np.arange(ymin, ymax, 1))


# Plot the linear function as a red line
plt.plot([xmin,xmax],[y3,y4],'r')

plt.show()
# Out:
# y =  1.8 x +  32.0

# %% [markdown]
# #### Graph Line & Zoom in and Zoom Out

# %%
# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

# Define the graphing function
def f(zoom):
    xmin = -zoom
    xmax = zoom
    ymin = -zoom
    ymax = zoom
    points = 10*xmax-xmin
    x = np.linspace(xmin, xmax, points) # to graph

    fig, ax = plt.subplots()
    plt.axis([xmin,xmax,ymin,ymax]) # window size
    plt.plot([xmin,xmax],[0,0],'black') # black x axis
    plt.plot([0,0],[ymin,ymax], 'black') # black y axis

    # Line 1
    y1 = 3*x**2 - 4
    plt.plot(x, y1)
    # plt.fill_between (x, y1, ymax, facecolor='green')

    # Line 2
    y2 = x
    plt.plot(x, y2)
    # plt.fill_between (x, y2, ymin, facecolor='blue')


    ax.set_xlabel("x values")
    ax.set_ylabel("y values")
    ax.set_title("Some Graph")
    ticks = int(round((xmax-xmin)/20))
    ax.set_xticks(np.arange(xmin, xmax, ticks))
    ax.set_yticks(np.arange(ymin, ymax, ticks))
    ax.grid(True)
    plt.show()

# Set up the slider
interactive_plot = interactive(f, zoom=(1,100))
interactive_plot
# Out:
# interactive(children=(IntSlider(value=50, description='zoom', min=1), Output()), _dom_classes=('widget-interac…

# %% [markdown]
# #### Solve and Graph a System Equation

# %%
from sympy import *
from sympy.plotting import plot
from sympy import sqrt

var('x y')

# First equation set equal to zero, ready to solve
first = -x**2 - y + 10
# first = sqrt(x) - y

# Second equation set equal to zero, ready to solve
second = 2*x**2 - 2*y - 4
# second = -x + 5 - y

# Solve - can be linear or nonlinear equations
# for loop to solve different equations
solution = nonlinsolve([first, second], (x, y)) #nonlinsolve -> 
for a in range(len(solution.args)):
    x_solution = solution.args[a][0]
    y_solution = solution.args[a][1]
    print("Solution = (", x_solution, ",", y_solution, ")")

# Sympy syntax for equation equal to zero, ready to factor
y_first = Eq(first,0)

# Sympy solve for y
y1 = solve(y_first,y)

# Same two steps for second equation
y_second = Eq(second,0)
y2 = solve(y_second,y)

# Show factored results
print("y = ", y1[0])
print("y = ", y2[0])

# Plot solution
x = symbols('x')
xmin = -10
xmax = 10
plot(y1[0], y2[0], (x,xmin,xmax))
# Out:
# Solution = ( sqrt(6) , 4 )
# Solution = ( -sqrt(6) , 4 )
# y =  10 - x**2
# y =  x**2 - 2

# %% [markdown]
# #### Save graph and download it to your computer

# %%
# use this when graphing

from google.colab import files

# to save and output graph
plt.savefig("abc.png")
plt.show()
files.download("abc.png")

# %% [markdown]
# #### Question 3

# %%
# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

# Define the graphing function
def f(zoom):
    xmin = -zoom
    xmax = zoom
    ymin = -zoom
    ymax = zoom
    points = 10*xmax-xmin
    # x = np.linspace(xmin, xmax, points)
    x = [0,5,10,15]

    fig, ax = plt.subplots()
    plt.axis([xmin,xmax,ymin,ymax]) # window size
    plt.plot([xmin,xmax],[0,0],'black') # black x axis
    plt.plot([0,0],[ymin,ymax], 'black') # black y axis

    # Change y1 to be any function
    y1 = [5,-10,-25,-40]
    plt.plot(x, y1, 'ro')
    
    ax.set_xlabel("x values")
    ax.set_ylabel("y values")
    ax.set_title("Some Graph")
    ticks = int(round((xmax-xmin)/10))
    ax.set_xticks(np.arange(xmin, xmax, ticks))
    ax.set_yticks(np.arange(ymin, ymax, ticks))
    ax.grid(True)
    plt.show()

# Set up the slider
interactive_plot = interactive(f, zoom=(1,100))
interactive_plot
# Out:
# interactive(children=(IntSlider(value=50, description='zoom', min=1), Output()), _dom_classes=('widget-interac…

# %% [markdown]
# ### Extra Problems
#
# On average across all industries, full-time employed Canadians worked 39.5 hours per week. If the typical adult requires 8 hours per day, what percentage of the hours in a single week are left over for personal activities?

# %%
# Answer
print(24*7 - 39.5 - 8*7)
# Out:
# 72.5

# %% [markdown]
# Housing starts in Winnipeg for the first half of the 2009 year were down 46.733% from 2008, when 1,500 new homes were started. How many housing starts were there in 2009?

# %%
# Answer
print(round(1500*(1 - 0.46733)))
# Out:
# 799

# %% [markdown]
# If dollar 9.99 is changed to $ 10.49, what is the percent change?

# %%
# Anwer
print((round((0.50 / 9.99)*100)),"%")
# Out:
# 5 %

# %% [markdown]
# $19.99 lowered by 10% is what dollar amount?

# %%
print(round(19.99*(1.00-0.10)))
# Out:
# 18

# %% [markdown]
# What amount when increased by 40% is $ 3,500

# %%
# x * (1 + rate) = new amount 
# x increased (*)
# x * 1.40 = 3500

print(round(3500/(1.40)))
# Out:
# 2500

# %% [markdown]
# A local baseball team sells tickets with two price zones. Seats behind the plate from first base to third base are priced at dollar 20 per ticket.
#
# All other seats down the base lines and in the outfield are priced at dollar 10 per ticket. At last night’s game, 5,332 fans were in attendance and total ticket revenue was $ 71,750. How many tickets in each zone were sold?

# %%
from sympy import *
from sympy.plotting import plot
from sympy import sqrt

var('x y')

# 20*x + 10*y = $ 71,7150
# x + y = 5332

# First equation set equal to zero, ready to solve
first = 20*x + 10*y -71750


# Second equation set equal to zero, ready to solve
second = x + y - 5332

# Solve - can be linear or nonlinear equations
# for loop to solve different equations
solution = nonlinsolve([first, second], (x, y)) #nonlinsolve -> 
for a in range(len(solution.args)):
    x_solution = solution.args[a][0]
    y_solution = solution.args[a][1]
    print("Solution = (", x_solution, ",", y_solution, ")")

# Sympy syntax for equation equal to zero, ready to factor
y_first = Eq(first,0)

# Sympy solve for y
y1 = solve(y_first,y)

# Same two steps for second equation
y_second = Eq(second,0)
y2 = solve(y_second,y)

# Show factored results
print("y = ", y1[0])
print("y = ", y2[0])

# Plot solution
x = symbols('x')
xmin = -10
xmax = 10
plot(y1[0], y2[0], (x,xmin,xmax))
# Out:
# Solution = ( 1843 , 3489 )
# y =  7175 - 2*x
# y =  5332 - x

# %% [markdown]
# Gabrielle is famous for her trail mix recipe. By weight, the recipe calls for 50% pretzels, 30% Cheerios, and 20% peanuts. She wants to make a 2 kg container of her mix. If pretzels cost $ 9.99/kg, Cheerios cost $6.99 kg, and peanuts cost $4.95 kg.
#
# What is the average cost per 100 g rounded to four decimals?

# %%
pretzel  = .5*2
cheerios = .3*2
peanuts  = .2*2

cost = pretzel*9.99 + cheerios*6.99 + peanuts*4.95

print(cost/20) # gram
# Out:
# 0.8082
